# %% [markdown]
# ## Contains all reported data for the six municipalities, except the reported data underlying figure 3
# ### The data are stored by storemagic so that they can be directly accessed by the scripts using them

# %%
#%load_ext lab_black

# %%
import numpy as np

# %%
def reported_data_Averoy():
    municipality = "Averoy"
    first_year = 2007
    last_year = 2021
    number_of_years = last_year - first_year + 1
    years = np.arange(first_year, last_year + 1, 1).tolist()

    # Seen deers per hour - total + farmland (infield) + forest (outfield)
    seen_deer_obs = [
        1.54,
        1.38,
        1.33,
        1.31,
        1.61,
        0.92,
        1.1,
        1.01,
        0.69,
        0.75,
        1.09,
        1.20,
        1.42,
        1.19,
        1.36,
    ]

    # Seen deer per hour - forest - no data
    seen_deer_obs_outfield = [0] * number_of_years

    # Seen deer per hour - farmland - no data
    seen_deer_obs_infield = [0] * number_of_years

    # Seen hinds per stag - farmland + forest
    hinds_per_stag_obs = [
        2.82,
        3.56,
        2.70,
        2.76,
        2.84,
        2.31,
        2.32,
        1.97,
        1.99,
        2.03,
        2.49,
        2.42,
        2.21,
        2.61,
        1.86,
    ]

    # Total number of deers harvested
    total_harvest = [
        198,
        228,
        259,
        279,
        270,
        208,
        221,
        227,
        215,
        230,
        204,
        278,
        333,
        418,
        433,
    ]

    # Sex and stage fractioning of the total harvest
    fraction_female_calves_harvested = [
        18.7,
        16.7,
        16.2,
        12.2,
        13.0,
        12.5,
        10.4,
        16.3,
        13.5,
        13.0,
        15.7,
        14.4,
        15.0,
        15.1,
        14.5,
    ]
    fraction_young_hinds_harvested = [
        15.7,
        18.9,
        29.3,
        25.8,
        25.6,
        21.6,
        25.3,
        20.3,
        19.5,
        19.6,
        19.1,
        23.7,
        21.0,
        23.4,
        23.6,
    ]
    fraction_adult_hinds_harvested = [
        20.7,
        18.9,
        30.1,
        23.3,
        21.9,
        23.6,
        27.6,
        23.8,
        21.4,
        19.6,
        18.6,
        20.1,
        25.5,
        25.6,
        29.1,
    ]

    fraction_male_calves_harvested = [
        20.7,
        15.8,
        15.1,
        12.9,
        13.0,
        13.5,
        13.1,
        9.7,
        13.0,
        15.2,
        16.7,
        14.0,
        14.1,
        12.7,
        16.9,
    ]
    fraction_young_stags_harvested = [
        13.1,
        18.9,
        5.8,
        14.3,
        15.6,
        16.3,
        12.7,
        18.1,
        18.1,
        17.0,
        18.1,
        16.9,
        11.7,
        13.6,
        9.5,
    ]
    fraction_adult_stags_harvested = [
        11.1,
        11.0,
        3.5,
        11.5,
        11.1,
        12.5,
        10.9,
        11.9,
        14.4,
        15.7,
        11.8,
        10.8,
        12.6,
        9.6,
        6.5,
    ]

    # Number of deers counted in the spring - farmland
    spring_counts = [
        1000,
        1000,
        1000,
        1000,
        1000,
        1000,
        1000,
        1000,
        1000,
        1000,
        1000,
        1000,
        1000,
        1000,
        1000,
    ]

    return (
        municipality,
        first_year,
        last_year,
        number_of_years,
        years,
        seen_deer_obs,
        seen_deer_obs_forest,
        seen_deer_obs_farmland,
        hinds_per_stag_obs,
        total_harvest,
        fraction_female_calves_harvested,
        fraction_young_hinds_harvested,
        fraction_adult_hinds_harvested,
        fraction_male_calves_harvested,
        fraction_young_stags_harvested,
        fraction_adult_stags_harvested,
        spring_counts,
    )

# %%
def reported_data_Tingvoll():
    municipality = "Tingvoll"
    first_year = 2007
    last_year = 2021
    number_of_years = last_year - first_year + 1
    years = np.arange(first_year, last_year + 1, 1).tolist()

    # Seen deers per hour - total + farmland + forest
    seen_deer_obs = [
        0.56,
        0.58,
        0.63,
        0.46,
        0.50,
        0.45,
        0.56,
        0.56,
        0.46,
        0.67,
        0.55,
        0.50,
        0.54,
        0.51,
        0.54,
    ]

    # Seen deers per hour - forest
    seen_deer_obs_outfield = [
        0.33,
        0.35,
        0.41,
        0.25,
        0.29,
        0.29,
        0.37,
        0.40,
        0.31,
        0.33,
        0.32,
        0.26,
        0.30,
        0.24,
        0.28,
    ]

    # Seen deers per hour - farmland
    seen_deer_obs_infield = [
        1.69,
        1.44,
        1.33,
        1.11,
        1.16,
        0.94,
        1.12,
        1.10,
        1.12,
        1.32,
        1.19,
        1.11,
        1.19,
        1.21,
        1.08,
    ]

    # Seen hinds per stag - farmland + forest
    hinds_per_stag_obs = [
        2.59,
        1.72,
        2.07,
        1.87,
        1.90,
        2.24,
        1.80,
        1.71,
        1.99,
        2.02,
        2.00,
        2.32,
        2.17,
        2.59,
        2.39,
    ]

    # Total number of deers harvested
    total_harvest = [
        457,
        514,
        554,
        576,
        519,
        422,
        481,
        539,
        590,
        589,
        579,
        719,
        639,
        685,
        694,
    ]

    # Sex and stage fractioning of the total harvest
    fraction_female_calves_harvested = [
        13.3,
        13.2,
        16.4,
        17.7,
        14.1,
        15.2,
        13.1,
        17.6,
        18.6,
        15.4,
        13.2,
        14.7,
        16.0,
        13.4,
        16.0,
    ]
    fraction_young_hinds_harvested = [
        19.5,
        19.3,
        16.4,
        14.1,
        16.2,
        19.2,
        17.3,
        17.6,
        19.3,
        18.0,
        14.3,
        17.9,
        17.5,
        17.8,
        17.6,
    ]
    fraction_adult_hinds_harvested = [
        19.9,
        24.9,
        26.0,
        25.7,
        26.2,
        21.3,
        19.1,
        20.8,
        16.3,
        22.6,
        22.1,
        23.4,
        22.8,
        24.4,
        22.2,
    ]

    fraction_male_calves_harvested = [
        18.2,
        17.9,
        17.1,
        17.7,
        16.0,
        15.2,
        16.0,
        17.4,
        14.7,
        12.9,
        18.1,
        15.6,
        17.2,
        17.4,
        17.9,
    ]
    fraction_young_stags_harvested = [
        13.6,
        12.6,
        10.1,
        12.7,
        11.9,
        14.7,
        17.5,
        13.0,
        15.3,
        15.3,
        14.5,
        14.9,
        11.7,
        13.7,
        14.1,
    ]
    fraction_adult_stags_harvested = [
        15.5,
        12.1,
        13.9,
        12.2,
        15.6,
        14.5,
        17.0,
        13.5,
        15.8,
        15.8,
        17.6,
        13.5,
        14.7,
        13.3,
        12.4,
    ]

    # Number of deers counted in the spring - farmland
    spring_counts = [
        663,
        776,
        813,
        692,
        711,
        736,
        584,
        1014,
        1094,
        923,
        1048,
        1250,
        1062,
        1223,
        1360,
    ]

    return (
        municipality,
        first_year,
        last_year,
        number_of_years,
        years,
        seen_deer_obs,
        seen_deer_obs_forest,
        seen_deer_obs_farmland,
        hinds_per_stag_obs,
        total_harvest,
        fraction_female_calves_harvested,
        fraction_young_hinds_harvested,
        fraction_adult_hinds_harvested,
        fraction_male_calves_harvested,
        fraction_young_stags_harvested,
        fraction_adult_stags_harvested,
        spring_counts,
    )

# %%
def reported_data_Surnadal():
    municipality = "Surnadal"
    first_year = 2007
    last_year = 2021
    number_of_years = last_year - first_year + 1
    years = np.arange(first_year, last_year + 1, 1).tolist()

    # Seen deers per hour - total + farmland + forest
    seen_deer_obs = [
        0.09,
        0.15,
        0.15,
        0.15,
        0.17,
        0.14,
        0.17,
        0.17,
        0.15,
        0.20,
        0.24,
        0.25,
        0.26,
        0.18,
        0.25,
    ]

    # Seen deers per hour - forest
    seen_deer_obs_outfield = [
        0.07,
        0.13,
        0.12,
        0.11,
        0.12,
        0.12,
        0.13,
        0.12,
        0.11,
        0.14,
        0.17,
        0.17,
        0.18,
        0.14,
        0.15,
    ]

    # Seen deers per hour - farmland
    seen_deer_obs_infield = [
        1.44,
        0.55,
        1.11,
        0.66,
        1.43,
        0.68,
        0.91,
        0.94,
        0.61,
        1.04,
        0.93,
        0.64,
        0.98,
        0.57,
        1.09,
    ]

    # Seen hinds per stag - farmland + forest
    hinds_per_stag_obs = [
        1.51,
        1.92,
        2.18,
        2.0,
        2.17,
        1.97,
        1.82,
        1.74,
        2.22,
        1.91,
        1.9,
        1.81,
        1.74,
        1.54,
        1.7,
    ]

    # Total number of deer harvested
    total_harvest = [
        369,
        426,
        453,
        497,
        433,
        384,
        393,
        375,
        387,
        416,
        439,
        498,
        601,
        507,
        490,
    ]

    # Sex and stage fractioning of the total harvest
    fraction_female_calves_harvested = [
        12.2,
        12.0,
        14.1,
        15.7,
        15.5,
        13.8,
        19.1,
        12.8,
        16.3,
        14.7,
        12.5,
        15.9,
        16.5,
        14.4,
        15.5,
    ]
    fraction_young_hinds_harvested = [
        14.1,
        12.0,
        15.0,
        15.1,
        13.4,
        14.1,
        12.5,
        13.6,
        11.9,
        11.3,
        12.5,
        11.6,
        8.5,
        9.9,
        9.4,
    ]
    fraction_adult_hinds_harvested = [
        20.3,
        19.2,
        22.3,
        20.7,
        23.8,
        22.7,
        21.1,
        19.2,
        22.0,
        21.4,
        20.7,
        24.3,
        26.6,
        24.7,
        23.1,
    ]
    fraction_male_calves_harvested = [
        15.4,
        17.8,
        14.3,
        15.1,
        16.2,
        14.8,
        11.7,
        16.0,
        16.5,
        13.2,
        14.8,
        13.7,
        16.5,
        14.2,
        14.5,
    ]
    fraction_young_stags_harvested = [
        15.7,
        17.1,
        13.9,
        12.7,
        12.9,
        15.1,
        16.0,
        17.6,
        13.2,
        17.8,
        17.3,
        13.7,
        13.3,
        14.6,
        16.9,
    ]
    fraction_adult_stags_harvested = [
        22.2,
        21.8,
        20.3,
        20.7,
        18.2,
        19.5,
        19.6,
        20.8,
        20.2,
        21.6,
        22.1,
        20.9,
        18.6,
        22.3,
        20.6,
    ]

    # Number of deers counted in the spring - farmland
    spring_counts = [
        773,
        755,
        644,
        793,
        618,
        737,
        654,
        625,
        789,
        814,
        795,
        916,
        1034,
        752,
        827,
    ]

    return (
        municipality,
        first_year,
        last_year,
        number_of_years,
        years,
        seen_deer_obs,
        seen_deer_obs_forest,
        seen_deer_obs_farmland,
        hinds_per_stag_obs,
        total_harvest,
        fraction_female_calves_harvested,
        fraction_young_hinds_harvested,
        fraction_adult_hinds_harvested,
        fraction_male_calves_harvested,
        fraction_young_stags_harvested,
        fraction_adult_stags_harvested,
        spring_counts,
    )

# %%
def reported_data_Sunndal():
    municipality = "Sunndal"
    first_year = 2007
    last_year = 2021
    number_of_years = last_year - first_year + 1
    years = np.arange(first_year, last_year + 1, 1).tolist()

    # Seen deers per hour - total + farmland + forest
    seen_deer_obs = [
        0.46,
        0.39,
        0.32,
        0.47,
        0.47,
        0.25,
        0.43,
        0.36,
        0.36,
        0.39,
        0.47,
        0.36,
        0.42,
        0.39,
        0.43,
    ]

    # Seen deers per hour - forest
    seen_deer_obs_outfield = [0] * number_of_years

    # Seen deers per hour - farmland
    seen_deer_obs_infield = [0] * number_of_years

    # Seen hinds per stag - farmland + forest
    hinds_per_stag_obs = [
        1.61,
        2.22,
        2.06,
        2.20,
        1.92,
        1.95,
        1.82,
        1.47,
        1.41,
        1.69,
        1.50,
        1.81,
        1.71,
        1.24,
        1.53,
    ]

    # Total number of deers harvested
    total_harvest = [
        442,
        454,
        420,
        482,
        446,
        399,
        461,
        364,
        388,
        464,
        529,
        511,
        477,
        504,
        544,
    ]

    # Sex and stage fractioning of the total harvest
    fraction_female_calves_harvested = [
        15.4,
        16.7,
        13.6,
        16.2,
        15.2,
        12.3,
        14.1,
        11.8,
        11.3,
        14.4,
        15.7,
        14.1,
        12.6,
        12.3,
        14.0,
    ]
    fraction_young_hinds_harvested = [
        10.0,
        12.1,
        12.6,
        13.9,
        15.9,
        13.8,
        15.6,
        17.6,
        16.8,
        12.5,
        13.6,
        19.2,
        20.8,
        13.5,
        17.5,
    ]
    fraction_adult_hinds_harvested = [
        22.6,
        20.0,
        23.8,
        24.7,
        20.4,
        26.1,
        17.4,
        19.0,
        18.3,
        19.2,
        19.5,
        18.8,
        18.9,
        24.4,
        20.8,
    ]

    fraction_male_calves_harvested = [
        16.7,
        17.8,
        17.1,
        14.5,
        15.5,
        13.5,
        15.8,
        14.6,
        14.7,
        17.0,
        14.6,
        14.3,
        14.3,
        15.4,
        16.0,
    ]
    fraction_young_stags_harvested = [
        16.3,
        16.3,
        12.6,
        12.9,
        11.9,
        16.0,
        17.1,
        16.2,
        18.8,
        18.5,
        16.8,
        16.4,
        16.6,
        16.7,
        14.2,
    ]
    fraction_adult_stags_harvested = [
        19.0,
        17.0,
        20.2,
        17.8,
        21.1,
        18.3,
        20.0,
        20.9,
        20.1,
        18.3,
        19.8,
        17.2,
        17.0,
        17.7,
        17.6,
    ]

    # Number of deers counted in the spring - farmland
    spring_counts = [
        507,
        513,
        274,
        421,
        427,
        436,
        319,
        452,
        560,
        512,
        720,
        568,
        726,
        866,
        865,
    ]

    return (
        municipality,
        first_year,
        last_year,
        number_of_years,
        years,
        seen_deer_obs,
        seen_deer_obs_forest,
        seen_deer_obs_farmland,
        hinds_per_stag_obs,
        total_harvest,
        fraction_female_calves_harvested,
        fraction_young_hinds_harvested,
        fraction_adult_hinds_harvested,
        fraction_male_calves_harvested,
        fraction_young_stags_harvested,
        fraction_adult_stags_harvested,
        spring_counts,
    )

# %%
def reported_data_Vestnes():
    municipality = "Vestnes"
    first_year = 2007
    last_year = 2021
    number_of_years = last_year - first_year + 1
    years = np.arange(first_year, last_year + 1, 1).tolist()

    # Seen deers per hour - total + farmland + forest
    seen_deer_obs = [
        0.699,
        0.673,
        0.658,
        0.689,
        0.580,
        0.728,
        0.494,
        0.482,
        0.528,
        0.660,
        0.669,
        0.369,
        0.687,
        0.621,
        0.727,
    ]

    # Seen deers per hour - forest
    seen_deer_obs_outfield = [
        0.459,
        0.399,
        0.378,
        0.418,
        0.399,
        0.476,
        0.267,
        0.312,
        0.292,
        0.435,
        0.413,
        0.206,
        0.463,
        0.424,
        0.525,
    ]

    # Seen deers per hour - farmland
    # Fourth element missing, so it was interpolated
    seen_deer_obs_infield = [
        1.039,
        1.217,
        1.083,
        0.997,
        0.846,
        1.186,
        0.801,
        0.688,
        0.920,
        0.992,
        1.041,
        0.580,
        1.009,
        0.888,
        1.022,
    ]

    # Seen hinds per stag - farmland + forest
    hinds_per_stag_obs = [
        2.08,
        1.55,
        1.55,
        1.95,
        1.66,
        2.07,
        1.76,
        1.74,
        1.64,
        1.85,
        1.97,
        1.99,
        1.77,
        1.85,
        1.49,
    ]

    # Total number of deers harvested
    total_harvest = [
        443,
        481,
        536,
        580,
        411,
        400,
        478,
        433,
        419,
        477,
        531,
        543,
        628,
        600,
        618,
    ]

    # Sex and stage fractioning of the total harvest
    fraction_female_calves_harvested = [
        16.5,
        18.7,
        14.9,
        17.8,
        14.1,
        15.3,
        15.3,
        13.6,
        17.4,
        14.7,
        16.8,
        18.0,
        13.5,
        16.0,
        14.7,
    ]
    fraction_young_hinds_harvested = [
        13.1,
        15.2,
        13.8,
        13.4,
        15.1,
        13.8,
        15.5,
        15.0,
        11.5,
        17.4,
        15.1,
        13.1,
        15.6,
        14.0,
        13.6,
    ]
    fraction_adult_hinds_harvested = [
        13.7,
        19.3,
        23.9,
        22.1,
        19.2,
        20.3,
        18.4,
        18.5,
        19.1,
        16.6,
        17.3,
        23.6,
        20.4,
        21.3,
        24.3,
    ]

    fraction_male_calves_harvested = [
        17.6,
        15.2,
        15.5,
        18.1,
        15.1,
        17.3,
        17.4,
        16.2,
        16.5,
        17.4,
        15.8,
        16.0,
        18.9,
        17.3,
        17.3,
    ]
    fraction_young_stags_harvested = [
        13.8,
        14.8,
        12.5,
        13.1,
        14.4,
        16.0,
        14.2,
        17.3,
        14.1,
        15.1,
        16.0,
        13.4,
        16.1,
        16.5,
        15.4,
    ]
    fraction_adult_stags_harvested = [
        15.3,
        16.8,
        19.4,
        15.5,
        22.1,
        17.5,
        19.2,
        19.4,
        21.5,
        18.9,
        19.0,
        15.8,
        15.4,
        14.8,
        14.7,
    ]

    # Number of deers counted in the spring - farmland
    # Removed last: 816 - 2022
    spring_counts = [
        612,
        771,
        600,
        784,
        636,
        777,
        644,
        803,
        899,
        843,
        917,
        695,
        953,
        981,
        695,
    ]

    return (
        municipality,
        first_year,
        last_year,
        number_of_years,
        years,
        seen_deer_obs,
        seen_deer_obs_forest,
        seen_deer_obs_farmland,
        hinds_per_stag_obs,
        total_harvest,
        fraction_female_calves_harvested,
        fraction_young_hinds_harvested,
        fraction_adult_hinds_harvested,
        fraction_male_calves_harvested,
        fraction_young_stags_harvested,
        fraction_adult_stags_harvested,
        spring_counts,
    )

# %%
def reported_data_Laerdal():
    municipality = "Laerdal"
    first_year = 2007
    last_year = 2021
    number_of_years = last_year - first_year + 1
    years = np.arange(first_year, last_year + 1, 1).tolist()

    # Seen deers per hour - total + farmland + forest
    # Fourth element missing, so it was interpolated
    seen_deer_obs = [
        0.21,
        0.33,
        0.19,
        0.22,
        0.25,
        0.23,
        0.28,
        0.31,
        0.24,
        0.28,
        0.35,
        0.21,
        0.23,
        0.24,
        0.23,
    ]

    # Seen deers per hour - forest
    # Fourth element missing, so it was interpolated
    seen_deer_obs_outfield = [
        0.19,
        0.27,
        0.16,
        0.19,
        0.22,
        0.18,
        0.22,
        0.23,
        0.20,
        0.24,
        0.29,
        0.18,
        0.17,
        0.20,
        0.17,
    ]

    # Seen deers per hour - farmland
    # Fourth element missing, so it was interpolated
    seen_deer_obs_infield = [
        1.78,
        1.49,
        0.67,
        0.875,
        1.08,
        1.37,
        2.08,
        1.59,
        1.16,
        1.10,
        1.13,
        0.64,
        1.41,
        1.18,
        1.78,
    ]

    # Seen hinds per stag - farmland + forest
    hinds_per_stag_obs = [
        2.10,
        1.15,
        1.39,
        1.94,
        1.66,
        1.67,
        1.60,
        1.93,
        1.72,
        1.83,
        1.78,
        1.81,
        1.89,
        2.08,
        1.48,
    ]

    # Total number of deers harvested
    total_harvest = [
        340,
        304,
        340,
        383,
        355,
        316,
        342,
        392,
        355,
        398,
        785,
        438,
        471,
        447,
        532,
    ]

    # Sex and stage fractioning of the total harvest
    fraction_female_calves_harvested = [
        14.4,
        14.5,
        16.2,
        14.4,
        13.8,
        16.1,
        17.0,
        14.3,
        11.8,
        15.1,
        14.9,
        16.2,
        17.0,
        17.9,
        16.0,
    ]
    fraction_young_hinds_harvested = [
        9.7,
        9.9,
        12.4,
        13.6,
        13.8,
        13.6,
        11.7,
        10.2,
        11.3,
        9.8,
        8.8,
        12.1,
        13.8,
        13.0,
        15.4,
    ]
    fraction_adult_hinds_harvested = [
        26.2,
        28.9,
        26.8,
        25.8,
        22.5,
        21.5,
        24.6,
        25.0,
        25.4,
        25.6,
        28.4,
        28.5,
        25.5,
        23.7,
        21.2,
    ]

    fraction_male_calves_harvested = [
        15.9,
        12.2,
        15.6,
        16.7,
        16.9,
        15.2,
        13.5,
        19.9,
        13.2,
        14.3,
        11.6,
        14.8,
        19.3,
        20.8,
        21.4,
    ]
    fraction_young_stags_harvested = [
        13.2,
        14.1,
        13.5,
        11.5,
        13.8,
        17.1,
        17.8,
        16.3,
        16.1,
        16.1,
        13.8,
        15.1,
        14.4,
        13.4,
        16.4,
    ]
    fraction_adult_stags_harvested = [
        20.6,
        20.4,
        15.4,
        18.0,
        19.2,
        16.5,
        15.5,
        14.3,
        22.3,
        19.1,
        22.5,
        13.2,
        10.0,
        11.2,
        9.6,
    ]

    # Number of deers counted in the spring - farmland
    spring_counts = [
        642,
        555,
        445,
        694,
        453,
        400,
        471,
        626,
        734,
        626,
        872,
        842,
        488,
        655,
        652,
    ]

    return (
        municipality,
        first_year,
        last_year,
        number_of_years,
        years,
        seen_deer_obs,
        seen_deer_obs_forest,
        seen_deer_obs_farmland,
        hinds_per_stag_obs,
        total_harvest,
        fraction_female_calves_harvested,
        fraction_young_hinds_harvested,
        fraction_adult_hinds_harvested,
        fraction_male_calves_harvested,
        fraction_young_stags_harvested,
        fraction_adult_stags_harvested,
        spring_counts,
    )

# %%
data_Averoy = reported_data_Averoy()
data_Tingvoll = reported_data_Tingvoll()
data_Surnadal = reported_data_Surnadal()
data_Sunndal = reported_data_Sunndal()
data_Vestnes = reported_data_Vestnes()
data_Laerdal = reported_data_Laerdal()

# %%
# https://ipython.org/ipython-doc/rel-0.12/config/extensions/storemagic.html
# %store data_Averoy
# %store data_Tingvoll
# %store data_Surnadal
# %store data_Sunndal
# %store data_Vestnes
# %store data_Laerdal
# Out:
# Stored 'data_Averoy' (tuple)
# Stored 'data_Tingvoll' (tuple)
# Stored 'data_Surnadal' (tuple)
# Stored 'data_Sunndal' (tuple)
# Stored 'data_Vestnes' (tuple)
# Stored 'data_Laerdal' (tuple)
